# %%
import pandas as pd

x = pd.read_csv('train.csv')
y = x.pop('Survived')

# %%
x.describe()
# Out:
# /Users/macuser/Documents/webapp/til/lib/python3.4/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000         NaN    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000         NaN    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000         NaN    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Age has NaN value so I'll put mean value
x['Age'].fillna(x['Age'].mean(), inplace=True)

x.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
numeric_variables = list(x.dtypes[x.dtypes  != 'object'].index)
x[numeric_variables].head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            1       3  22.0      1      0   7.2500
# 1            2       1  38.0      1      0  71.2833
# 2            3       3  26.0      0      0   7.9250
# 3            4       1  35.0      1      0  53.1000
# 4            5       3  35.0      0      0   8.0500
